# %%
# Fun some setup for the project
# Silence annoying pytorch deprecated warnings
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
from eval_nll import *
import numpy as np
# %matplotlib inline

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # AIDS Dataset Notebook. Treat AIDS class 1 (Inactive Molecules) as the normal dataset and AIDS class 0 (Active molecules) as the anomalous dataset

# %%
nll_dir = 'nll/AIDS_1'

# %%
# Step 1
# Load the training and test nll predictions to test generalization
train_nlls = load_avg_nlls(nll_dir, 'train')
test_nlls = load_avg_nlls(nll_dir, 'test')

# Plot distribtutions
fig, ax_compare = compare_dist([train_nlls, test_nlls], ['AIDS_1 Train', 'AIDS_1 Test'], 'Train vs. Test Distributions')

# %%
# Step 2 
# Compare the test graphs from the normal class nlls with the anomalous graph nlls
anom_nlls = load_avg_nlls(nll_dir, 'AIDS_0')

# Plot distribtutions
fig, ax_compare = compare_dist([train_nlls, test_nlls, anom_nlls], ['AIDS_1 Train (norm)', 'AIDS_1 Test (norm)', 'AIDS_0 (anom)'], 'Nomral Vs. Anomalous Class distributions')
