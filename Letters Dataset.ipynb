# %%
# Fun some setup for the project
# Silence annoying pytorch deprecated warnings
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
from eval_nll import *
import numpy as np
# %matplotlib inline

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Letter_low Dataset Notebook. Treat Letter class 1 (letter N) as the normal dataset and other letters as anomalous

# %%
nll_dir = 'nll/Letter-low_1'

# %%
# Step 1
# Load the training and test nll predictions to test generalization
train_nlls = load_avg_nlls(nll_dir, 'train')
test_nlls = load_avg_nlls(nll_dir, 'test')

# Plot distribtutions
fig, ax_compare = compare_dist([train_nlls, test_nlls], ['Letter-low_1 Train', 'Letter-low_1 Test'], 'Train vs. Test Distributions')

# %%
# Step 2 
# Compare the test graphs from the normal class nlls with the anomalous graph nlls
anom_nlls_m = load_avg_nlls(nll_dir, 'Letter-low_14')
anom_nlls_k = load_avg_nlls(nll_dir, 'Letter-low_0')
anom_nlls_z = load_avg_nlls(nll_dir, 'Letter-low_3')
anom_nlls_x = load_avg_nlls(nll_dir, 'Letter-low_5')
anom_nlls_f = load_avg_nlls(nll_dir, 'Letter-low_6')
anom_nlls_y = load_avg_nlls(nll_dir, 'Letter-low_8')
anom_nlls_a = load_avg_nlls(nll_dir, 'Letter-low_11')

nlls = [train_nlls, test_nlls, anom_nlls_m, anom_nlls_k, anom_nlls_z, anom_nlls_x, anom_nlls_f, anom_nlls_y, anom_nlls_a]
labels = ['N (norm)', 'N Test (norm)', 'M (anom)', 'K (anom)', 'Z (anom)', 'X (anom)', 'F (anom)', 'Y (anom)', 'A (anom)']
# Plot distribtutions
fig, ax_compare = compare_dist(nlls, labels, 'N Vs. All other letter distributions')

# %%
# Step 2 
# Compare the test graphs from the normal class nlls with the anomalous graph nlls
anom_nlls_m = load_avg_nlls(nll_dir, 'Letter-low_14')

nlls = [train_nlls, test_nlls, anom_nlls_m]
labels = ['N (norm)', 'N Test (norm)', 'M (anom)']
# Plot distribtutions
fig, ax_compare = compare_dist(nlls, labels, 'N Vs. M distributions')

# %%
# Step 2 
# Compare the test graphs from the normal class nlls with the anomalous graph nlls
anom_nlls_k = load_avg_nlls(nll_dir, 'Letter-low_0')

nlls = [train_nlls, test_nlls, anom_nlls_k]
labels = ['N (norm)', 'N Test (norm)', 'K (anom)']
# Plot distribtutions
fig, ax_compare = compare_dist(nlls, labels, 'N Vs. K distributions')

# %%
# Step 2 
# Compare the test graphs from the normal class nlls with the anomalous graph nlls
anom_nlls_z = load_avg_nlls(nll_dir, 'Letter-low_3')

nlls = [train_nlls, test_nlls, anom_nlls_k]
labels = ['N (norm)', 'N Test (norm)', 'Z (anom)']
# Plot distribtutions
fig, ax_compare = compare_dist(nlls, labels, 'N Vs. Z distributions')

# %%
# Step 2 
# Compare the test graphs from the normal class nlls with the anomalous graph nlls
anom_nlls_x = load_avg_nlls(nll_dir, 'Letter-low_5')

nlls = [train_nlls, test_nlls, anom_nlls_x]
labels = ['N (norm)', 'N Test (norm)', 'X (anom)']
# Plot distribtutions
fig, ax_compare = compare_dist(nlls, labels, 'N Vs. X distributions')

# %%
# Step 2 
# Compare the test graphs from the normal class nlls with the anomalous graph nlls
anom_nlls_f = load_avg_nlls(nll_dir, 'Letter-low_6')

nlls = [train_nlls, test_nlls, anom_nlls_f]
labels = ['N (norm)', 'N Test (norm)', 'F (anom)']
# Plot distribtutions
fig, ax_compare = compare_dist(nlls, labels, 'N Vs. F distributions')

# %%
# Step 2 
# Compare the test graphs from the normal class nlls with the anomalous graph nlls
anom_nlls_y = load_avg_nlls(nll_dir, 'Letter-low_8')

nlls = [train_nlls, test_nlls, anom_nlls_y]
labels = ['N (norm)', 'N Test (norm)', 'Y (anom)']
# Plot distribtutions
fig, ax_compare = compare_dist(nlls, labels, 'N Vs. Y distributions')

# %%
# Step 2 
# Compare the test graphs from the normal class nlls with the anomalous graph nlls
anom_nlls_a = load_avg_nlls(nll_dir, 'Letter-low_11')

nlls = [train_nlls, test_nlls, anom_nlls_a]
labels = ['N (norm)', 'N Test (norm)', 'A (anom)']
# Plot distribtutions
fig, ax_compare = compare_dist(nlls, labels, 'N Vs. A distributions')
