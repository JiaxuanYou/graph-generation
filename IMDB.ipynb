# %%
# Fun some setup for the project
# Silence annoying pytorch deprecated warnings
import warnings
warnings.filterwarnings("ignore")

import matplotlib.pyplot as plt
from eval_nll import *
import numpy as np
# %matplotlib inline

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # IMDB Multi Dataset Notebook. Treat IMDB class 1 as the normal dataset and IMDB classes 2/3 as the anomalous dataset

# %%
nll_dir = 'nll/IMDB-MULTI_1'

# %%
# Step 1
# Load the training and test nll predictions to test generalization
train_nlls = load_avg_nlls(nll_dir, 'train')
test_nlls = load_avg_nlls(nll_dir, 'test')

# Plot distribtutions
fig, ax_compare = compare_dist([train_nlls, test_nlls], ['IMDB-MULTI_1 Train', 'IMDB-MULTI_1 Test'], 'Train vs. Test Distributions')

# %%
# Step 2 
# Compare the test graphs from the normal class nlls with the anomalous graph nlls
anom_nlls = load_avg_nlls(nll_dir, 'IMDB-MULTI_2')

# Plot distribtutions
fig, ax_compare = compare_dist([train_nlls, test_nlls, anom_nlls], ['IMDB-MULTI_1 Train (norm)', 'IMDB-MULTI_1 Test (norm)', 'IMDB-MULTI_2 (anom)'], 'Nomral Vs. Anomalous Class distributions')

# %%
# Step 2 
# Compare the test graphs from the normal class nlls with the anomalous graph nlls
anom_nlls = load_avg_nlls(nll_dir, 'IMDB-MULTI_3')

# Plot distribtutions
fig, ax_compare = compare_dist([train_nlls, test_nlls, anom_nlls], ['IMDB-MULTI_1 Train (norm)', 'IMDB-MULTI_1 Test (norm)', 'IMDB-MULTI_3 (anom)'], 'Nomral Vs. Anomalous Class distributions')
